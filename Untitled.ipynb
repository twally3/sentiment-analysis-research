# %%
import tensorflow as tf
import numpy as np
save_file = './model.ckpt'
tf.reset_default_graph()

# %%
g = open('reviews.txt','r')
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r')
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0:1]
# Out:
# ['bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   ']

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
review_vocab = set()
for review in reviews:
    for word in review.split(' '):
        review_vocab.add(word)

review_vocab = list(review_vocab)

label_vocab = set()
for label in labels:
    label_vocab.add(label)

label_vocab = list(label_vocab)

review_vocab_size = len(review_vocab)
label_vocab_size = len(label_vocab)

word2index = {}
for i, word in enumerate(review_vocab):
    word2index[word] = i
    
label2index = {}
for i, label in enumerate(label_vocab):
    label2index[label] = i

# %%
review_vocab
# Out:
# ['',
#  'buick',
#  'pigface',
#  'investing',
#  'dogpatch',
#  'kwame',
#  'vacillate',
#  'et',
#  'mathurin',
#  'homesteading',
#  'ofcourse',
#  'macliammir',
#  'aryana',
#  'expendable',
#  'contaminating',
#  'chapeaux',
#  'author',
#  'yack',
#  'swampy',
#  'insignificant',
#  'surrealness',
#  'levels',
#  'escort',
#  'atrociousthe',
#  'slithered',
#  'scissors',
#  'transcendence',
#  'protected',
#  'combed',
#  'alrite',
#  'unassured',
#  'sefa',
#  'immediacy',
#  'gabrielle',
#  'phieffer',
#  'asco',
#  'cache',
#  'guild',
#  'counterstrike',
#  'tolerans',
#  'lunacy',
#  'entitle',
#  'abridge',
#  'yojimbo',
#  'calibration',
#  'galaxina',
#  'samot',
#  'giornate',
#  'stance',
#  'zimmerman',
#  'meddle',
#  'luckely',
#  'supertroopers',
#  'queequeg',
#  'latterday',
#  'saxaphone',
#  'questions',
#  'novelized',
#  'fontanelles',
#  'truckers',
#  'brand',
#  'psicoanalitical',
#  'rinne',
#  'markup',
#  'canoe',
#  'moly',
#  'megalunged',
#  'tyrannosaur',
#  'remake',
#  'libertine',
#  'ummmm',
#  'blackens',
#  'cams',
#  'genma',
#  'stagehands',
#  'rightly',
#  'appalingly',
#  'misses',
#  'plissken',
#  'humors',
#  'whishaw',
#  'clientle',
#  'gerhard',
#  'typifies',
#  'baxter',
#  'errand',
#  'wigged',
#  'pigalle',
#  'brulier',
#  'ides',
#  'gauteng',
#  'conclusiondirector',
#  'govinda',
#  'seize',
#  'rents',
#  'imperialism',
#  'truckloads',
#  'bugsy',
#  'recognizing',
#  'carney',
#  'shumaker',
#  'graber',
#  'predilections',
#  'geisha',
#  'worry',
#  'monogram',
#  'whoops',
#  'pando',
#  'kafka',
#  'chompers',
#  'pterodactyl',
#  'neuroses',
#  'bedchamber',
#  'contracter',
#  'narcoleptic',
#  'daneldoradoyahoo',
#  'dramatical',
#  'cutest',
#  'faxes',
#  'bejarano',
#  'gandhian',
#  'kant',
#  'mutates',
#  'dining',
#  'worrying',
#  'strikebreakers',
#  'rightful',
#  'plana',
#  'effervescent',
#  'legal',
#  'bravura',
#  'franoise',
#  'dougie',
#  'columned',
#  'salum',
#  'indianised',
#  'greenlit',
#  'mikhalkov',
#  'informercial',
#  'thatched',
#  'pumped',
#  'meghan',
#  'rolls',
#  'ized',
#  'headings',
#  'uncovered',
#  'candle',
#  'cod',
#  'wrapping',
#  'obtuseness',
#  'wildside',
#  'intruders',
#  'capitalizes',
#  'edwedge',
#  'rippings',
#  'repossessed',
#  'overemoting',
#  'boopous',
#  'socialism',
#  'date',
#  'jelly',
#  'north',
#  'yugoslavian',
#  'pokemon',
#  'hearfelt',
#  'manassas',
#  'bedsit',
#  'unsynchronised',
#  'barnacles',
#  'fllm',
#  'millardo',
#  'jesues',
#  'sewage',
#  'yamasato',
#  'julliard',
#  'dalrymple',
#  'demerille',
#  'tratment',
#  'deportation',
#  'performancein',
#  'normative',
#  'anatomie',
#  'mysteriosity',
#  'frost',
#  'condenses',
#  'appearing',
#  'lupus',
#  'slowdown',
#  'mccullum',
#  'rutledge',
#  'facilitated',
#  'telfair',
#  'nakadai',
#  'zombie',
#  'unglued',
#  'voce',
#  'sotd',
#  'engrossed',
#  'horrify',
#  'fluent',
#  'brokers',
#  'pak',
#  'delaying',
#  'wotw',
#  'unshakable',
#  'moonstone',
#  'niall',
#  'copulation',
#  'keels',
#  'hoover',
#  'artistes',
#  'bullsh',
#  'unsuccessful',
#  'baaaaad',
#  'blob',
#  'nacional',
#  'leroux',
#  'parentally',
#  'strudel',
#  'winslet',
#  'gras',
#  'intertwain',
#  'avenues',
#  'untraditional',
#  'legality',
#  'maiga',
#  'surrogated',
#  'drunkard',
#  'hussy',
#  'criminality',
#  'chester',
#  'summarising',
#  'animalplanet',
#  'nadia',
#  'duddley',
#  'granddad',
#  'christophe',
#  'trema',
#  'brink',
#  'unwholesome',
#  'haarman',
#  'dose',
#  'skoda',
#  'necrophiliac',
#  'cloeck',
#  'yester',
#  'kiddie',
#  'firgens',
#  'anyhoo',
#  'publicist',
#  'deherrera',
#  'wren',
#  'froud',
#  'farina',
#  'endemic',
#  'sizzling',
#  'vallejo',
#  'coyly',
#  'voluntarily',
#  'evocatively',
#  'shipiro',
#  'pelican',
#  'detectable',
#  'marx',
#  'geste',
#  'profligate',
#  'reason',
#  'perfidy',
#  'inbound',
#  'afresh',
#  'anais',
#  'corniest',
#  'reuniting',
#  'kantor',
#  'agitated',
#  'verdone',
#  'yourself',
#  'intersection',
#  'panting',
#  'dooooosie',
#  'odor',
#  'rein',
#  'bile',
#  'kake',
#  'caroll',
#  'bonaerense',
#  'fret',
#  'waite',
#  'selby',
#  'booooring',
#  'nun',
#  'sanpro',
#  'mija',
#  'favoritesyou',
#  'guiseppe',
#  'hjelmet',
#  'lucci',
#  'sooner',
#  'intergroup',
#  'tenderness',
#  'fbl',
#  'basks',
#  'angle',
#  'guignol',
#  'definitley',
#  'urdu',
#  'irate',
#  'entirelly',
#  'jacinto',
#  'maybes',
#  'apperance',
#  'imprimatur',
#  'reconstituirea',
#  'funfair',
#  'scotch',
#  'campaigned',
#  'faux',
#  'andre',
#  'bugged',
#  'emasculated',
#  'gummy',
#  'burnout',
#  'gunsmoke',
#  'othenin',
#  'catfights',
#  'sunscreen',
#  'tangentially',
#  'lifeguards',
#  'coalesce',
#  'loggia',
#  'melo',
#  'correctly',
#  'dishing',
#  'candyman',
#  'colonialism',
#  'blum',
#  'mandartory',
#  'ondrej',
#  'butterick',
#  'sixgun',
#  'recomment',
#  'decayed',
#  'demoralised',
#  'disturb',
#  'jacks',
#  'romford',
#  'farnsworth',
#  'challnges',
#  'garbagemen',
#  'around',
#  'buckaroo',
#  'disinterested',
#  'resolves',
#  'trashiest',
#  'annex',
#  'artwork',
#  'ephemerality',
#  'tact',
#  'loveday',
#  'fruits',
#  'kenitalia',
#  'overshadowing',
#  'darkening',
#  'hersholt',
#  'squished',
#  'heathcliffe',
#  'letourneau',
#  'szabo',
#  'cheech',
#  'squeals',
#  'dena',
#  'shenzi',
#  'destabilize',
#  'interessant',
#  'diaboliques',
#  'supertexts',
#  'hokiest',
#  'saratoga',
#  'kennicut',
#  'shone',
#  'solvency',
#  'uld',
#  'sinuous',
#  'cardinal',
#  'screwup',
#  'schedulers',
#  'kyrptonite',
#  'tushies',
#  'baulk',
#  'pics',
#  'gaining',
#  'enchantment',
#  'eraticate',
#  'idi',
#  'pessimistic',
#  'layton',
#  'mithun',
#  'hobgobblins',
#  'recurring',
#  'powering',
#  'caravan',
#  'hitchhikers',
#  'underpar',
#  'oberoi',
#  'undesirables',
#  'totall',
#  'bild',
#  'coyote',
#  'kindled',
#  'inauthentic',
#  'activism',
#  'doping',
#  'stapp',
#  'delpy',
#  'woche',
#  'unprovokedly',
#  'cozy',
#  'bogroll',
#  'unspun',
#  'sanitizing',
#  'corenblith',
#  'familiarized',
#  'malplaced',
#  'jerzee',
#  'coos',
#  'cover',
#  'meritorious',
#  'articulately',
#  'raking',
#  'mulgrew',
#  'bobby',
#  'bowdlerise',
#  'slurs',
#  'pirouette',
#  'shiniest',
#  'slvia',
#  'blooey',
#  'zzzzzzzzzzzz',
#  'irritatingly',
#  'anee',
#  'russianness',
#  'topped',
#  'leporid',
#  'hosing',
#  'ulises',
#  'barcode',
#  'erase',
#  'luzhini',
#  'informed',
#  'stoic',
#  'fukuoka',
#  'kidnap',
#  'choirs',
#  'lashelle',
#  'expletive',
#  'closups',
#  'overdo',
#  'knowledge',
#  'cerebrally',
#  'junk',
#  'reeeaally',
#  'daughters',
#  'ibanez',
#  'blinders',
#  'liquid',
#  'counts',
#  'msf',
#  'core',
#  'preconditions',
#  'exceeded',
#  'grubbing',
#  'polarizes',
#  'pestilence',
#  'generification',
#  'ziv',
#  'otherworldly',
#  'cafeteria',
#  'ware',
#  'genealogy',
#  'beggins',
#  'schade',
#  'funding',
#  'hitlerthe',
#  'crosscoe',
#  'kerri',
#  'daker',
#  'zzzzzzzz',
#  'bowen',
#  'gutenberg',
#  'commence',
#  'dungeon',
#  'babyhood',
#  'floradora',
#  'mortar',
#  'inbreed',
#  'auld',
#  'harping',
#  'mortality',
#  'stymie',
#  'disguise',
#  'bromwell',
#  'fuhrer',
#  'huzzah',
#  'storytellers',
#  'looking',
#  'jibes',
#  'castigates',
#  'ruled',
#  'unfairly',
#  'jabs',
#  'pup',
#  'plagiarize',
#  'surfing',
#  'inventor',
#  'egoist',
#  'dammes',
#  'naughtier',
#  'overwhlelming',
#  'dusan',
#  'voting',
#  'grispin',
#  'frontiers',
#  'confidante',
#  'tilted',
#  'teahouse',
#  'virgine',
#  'uncinematic',
#  'laid',
#  'psychosomatic',
#  'infusion',
#  'looming',
#  'loulou',
#  'blister',
#  'conspicuous',
#  'fat',
#  'gussets',
#  'seafront',
#  'mencia',
#  'lorica',
#  'mantels',
#  'hamburgers',
#  'ti',
#  'ministry',
#  'watched',
#  'musicality',
#  'synthesizes',
#  'applying',
#  'interleave',
#  'benet',
#  'stimulations',
#  'impartially',
#  'lycanthropy',
#  'blowhards',
#  'mufasa',
#  'galen',
#  'duplicitous',
#  'kaddiddlehopper',
#  'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'nerdish',
#  'foppish',
#  'guffawed',
#  'cule',
#  'roughie',
#  'tractored',
#  'trattoria',
#  'bmx',
#  'junkies',
#  'snowed',
#  'lewdness',
#  'klause',
#  'revisiting',
#  'mohicans',
#  'cinematicism',
#  'occupy',
#  'bredon',
#  'mad',
#  'crewed',
#  'bittinger',
#  'ravaging',
#  'westbridge',
#  'socioty',
#  'acquittal',
#  'speedy',
#  'expanse',
#  'yeop',
#  'natella',
#  'elly',
#  'achilles',
#  'barbet',
#  'assessments',
#  'mounds',
#  'elton',
#  'patrician',
#  'adachi',
#  'purport',
#  'ate',
#  'aesthetically',
#  'tipp',
#  'mcdoakes',
#  'sand',
#  'militarily',
#  'injuries',
#  'gianni',
#  'insinuates',
#  'teeeell',
#  'wust',
#  'sogo',
#  'gallows',
#  'tomie',
#  'garden',
#  'nativity',
#  'blockhead',
#  'steamers',
#  'alte',
#  'pantoliano',
#  'belongings',
#  'mosaic',
#  'blimps',
#  'ursla',
#  'commissions',
#  'naboombu',
#  'kickboxer',
#  'differential',
#  'unzip',
#  'wright',
#  'pastor',
#  'offspring',
#  'manat',
#  'promoting',
#  'katch',
#  'kashakim',
#  'call',
#  'conservation',
#  'khialdi',
#  'uninformative',
#  'neilsen',
#  'won',
#  'kyonki',
#  'quicksilver',
#  'analysts',
#  'wagner',
#  'acing',
#  'roommates',
#  'crowded',
#  'femi',
#  'pearly',
#  'plummeting',
#  'avid',
#  'wahhhhh',
#  've',
#  'straddling',
#  'nation',
#  'af',
#  'schmoozed',
#  'banjos',
#  'succinctly',
#  'absentee',
#  'ceos',
#  'australian',
#  'tohs',
#  'germaphobe',
#  'imprisoning',
#  'truism',
#  'disase',
#  'butt',
#  'mcculley',
#  'density',
#  'penitently',
#  'stanojlo',
#  'probate',
#  'farming',
#  'nastiness',
#  'imaginable',
#  'tolkein',
#  'formulatic',
#  'loek',
#  'sharpens',
#  'devolved',
#  'farenheight',
#  'swooned',
#  'motherdid',
#  'opus',
#  'wealthiest',
#  'glommed',
#  'insinuations',
#  'objectification',
#  'batzella',
#  'scoundrel',
#  'cena',
#  'fingertips',
#  'shabnam',
#  'birdie',
#  'hitch',
#  'weel',
#  'align',
#  'sharps',
#  'usaf',
#  'krushgroove',
#  'krell',
#  'immense',
#  'chetas',
#  'corto',
#  'targetting',
#  'schappert',
#  'notise',
#  'workers',
#  'q',
#  'queen',
#  'soulful',
#  'benson',
#  'helmuth',
#  'occultism',
#  'stros',
#  'booker',
#  'spitted',
#  'neurotics',
#  'tuberculosis',
#  'sensous',
#  'judas',
#  'pokes',
#  'rape',
#  'mathematically',
#  'apocryphal',
#  'benevolent',
#  'symbolizations',
#  'beringer',
#  'strate',
#  'impressionism',
#  'bingen',
#  'gethsemane',
#  'placidly',
#  'malkovichian',
#  'hesitancy',
#  'nui',
#  'ingredients',
#  'manhandles',
#  'easily',
#  'deadness',
#  'dull',
#  'rugby',
#  'gratuitus',
#  'minty',
#  'unforgiving',
#  'softest',
#  'shank',
#  'aff',
#  'imprison',
#  'transatlantic',
#  'tendo',
#  'averagousity',
#  'harried',
#  'fitted',
#  'maladriots',
#  'wanderers',
#  'haranguing',
#  'muro',
#  'waxworks',
#  'emma',
#  'clichs',
#  'upheavals',
#  'fragmentaric',
#  'ludivine',
#  'ritterkreuz',
#  'implanted',
#  'conjoined',
#  'potenta',
#  'galvanize',
#  'chocking',
#  'phelps',
#  'tilton',
#  'scrapbook',
#  'farreley',
#  'perabo',
#  'tarrinno',
#  'sobbingly',
#  'amat',
#  'illuminator',
#  'oral',
#  'moviemusereviews',
#  'arsehole',
#  'yidische',
#  'disappointment',
#  'launch',
#  'pugilist',
#  'prohibitions',
#  'seasickness',
#  'hopkirk',
#  'elucubrate',
#  'keanu',
#  'darstardy',
#  'forrest',
#  'photos',
#  'hotheads',
#  'nickelodean',
#  'cresus',
#  'somberness',
#  'defenseless',
#  'dalle',
#  'horrifically',
#  'kel',
#  'trifling',
#  'hunky',
#  'omens',
#  'synopsize',
#  'intersperse',
#  'piecing',
#  'woodchipper',
#  'decieve',
#  'emmanuelle',
#  'sandlers',
#  'horrorfilm',
#  'jeeves',
#  'toreson',
#  'circumscribe',
#  'heather',
#  'ieeee',
#  'mockmuntaries',
#  'susco',
#  'ridley',
#  'guility',
#  'spoilerphobic',
#  'humiliates',
#  'classicists',
#  'haiduck',
#  'abernathy',
#  'petey',
#  'eastwoods',
#  'duprez',
#  'sinbad',
#  'lashley',
#  'simulated',
#  'mandibles',
#  'shard',
#  'disengorges',
#  'collude',
#  'prat',
#  'panettiere',
#  'foggy',
#  'kenovic',
#  'admitt',
#  'newcastle',
#  'slayn',
#  'cappomaggi',
#  'yauman',
#  'wu',
#  'quietus',
#  'dispassionate',
#  'giurgiu',
#  'cay',
#  'scaramouche',
#  'bruckheimer',
#  'engraved',
#  'unearp',
#  'misperceived',
#  'ipcress',
#  'grue',
#  'stella',
#  'hotdog',
#  'interdimensional',
#  'lerner',
#  'denouements',
#  'grimstead',
#  'justifies',
#  'unavliable',
#  'motherly',
#  'dantesque',
#  'plastrons',
#  'trample',
#  'richart',
#  'coolish',
#  'lead',
#  'test',
#  'aip',
#  'shakiness',
#  'estimate',
#  'lash',
#  'tickling',
#  'discontents',
#  'brickman',
#  'fails',
#  'yorga',
#  'pocket',
#  'indolently',
#  'characterisation',
#  'halop',
#  'mger',
#  'neighbourhoods',
#  'murphy',
#  'adolescent',
#  'iliad',
#  'dodged',
#  'masochism',
#  'amusements',
#  'imagesi',
#  'unshowy',
#  'males',
#  'finland',
#  'bff',
#  'indecision',
#  'ventured',
#  'proclaimed',
#  'wardrobes',
#  'ampas',
#  'banned',
#  'sexiest',
#  'snider',
#  'magna',
#  'muddies',
#  'humongous',
#  'prehensile',
#  'disillusioning',
#  'taught',
#  'longed',
#  'caleb',
#  'hucksters',
#  'eeeeh',
#  'heyward',
#  'metalhead',
#  'rapprochement',
#  'untypically',
#  'smittened',
#  'pols',
#  'inwardly',
#  'conscious',
#  'surnames',
#  'percepts',
#  'rotj',
#  'ducky',
#  'safely',
#  'aby',
#  'shagayu',
#  'historicaly',
#  'mirrors',
#  'stunning',
#  'doses',
#  'given',
#  'androgynous',
#  'faustino',
#  'redefines',
#  'embraces',
#  'electric',
#  'starchy',
#  'lafanu',
#  'fincher',
#  'panties',
#  'heyerdahl',
#  'ntuba',
#  'merit',
#  'divulged',
#  'potboiler',
#  'refrains',
#  'suddenness',
#  'monteiro',
#  'imparts',
#  'wnk',
#  'bulworth',
#  'calvary',
#  'phoned',
#  'meaneys',
#  'troops',
#  'dingy',
#  'pulitzer',
#  'weirdos',
#  'herzegovina',
#  'pequod',
#  'lizabeth',
#  'leeched',
#  'jealousy',
#  'crashes',
#  'twistings',
#  'decadent',
#  'motive',
#  'hold',
#  'danniele',
#  'regeneration',
#  'suba',
#  'latching',
#  'zaz',
#  'skilful',
#  'soto',
#  'compiler',
#  'cosimo',
#  'wil',
#  'hardest',
#  'chin',
#  'allende',
#  'gorehounds',
#  'modus',
#  'ouroboros',
#  'zig',
#  'labs',
#  'dalliance',
#  'prc',
#  'commendation',
#  'ana',
#  'melding',
#  'barreling',
#  'descartes',
#  'raily',
#  'studies',
#  ...]

# %%
label_vocab
# Out:
# ['POSITIVE', 'NEGATIVE']

# %%
word2index
# Out:
# {'': 0,
#  'buick': 1,
#  'pigface': 2,
#  'investing': 3,
#  'dogpatch': 4,
#  'woodenly': 70573,
#  'kwame': 5,
#  'vacillate': 6,
#  'et': 7,
#  'mathurin': 8,
#  'ofcourse': 10,
#  'macliammir': 11,
#  'aryana': 12,
#  'expendable': 13,
#  'swampy': 18,
#  'chapeaux': 15,
#  'author': 16,
#  'yack': 17,
#  'surrealness': 20,
#  'levels': 21,
#  'atrociousthe': 23,
#  'slithered': 24,
#  'scissors': 25,
#  'transcendence': 26,
#  'protected': 27,
#  'combed': 28,
#  'reanimated': 24622,
#  'cop': 49521,
#  'unassured': 30,
#  'sefa': 31,
#  'immediacy': 32,
#  'asco': 35,
#  'cache': 36,
#  'guild': 37,
#  'tolerans': 39,
#  'maris': 59361,
#  'lunacy': 40,
#  'entitle': 41,
#  'booklet': 37066,
#  'abridge': 42,
#  'yojimbo': 43,
#  'calibration': 44,
#  'herringbone': 24628,
#  'samot': 46,
#  'giornate': 47,
#  'stance': 48,
#  'supertroopers': 52,
#  'luckely': 51,
#  'queequeg': 53,
#  'homesteading': 9,
#  'latterday': 54,
#  'saxaphone': 55,
#  'questions': 56,
#  'truckers': 59,
#  'psicoanalitical': 61,
#  'rinne': 62,
#  'markup': 63,
#  'canoe': 64,
#  'moly': 65,
#  'fannie': 61824,
#  'megalunged': 66,
#  'tyrannosaur': 67,
#  'jeremey': 24634,
#  'remake': 68,
#  'libertine': 69,
#  'blackens': 71,
#  'warmer': 71751,
#  'genma': 73,
#  'heroe': 19062,
#  'gilberte': 70056,
#  'stagehands': 74,
#  'rightly': 75,
#  'appalingly': 76,
#  'misses': 77,
#  'plissken': 78,
#  'contaminating': 14,
#  'humors': 79,
#  'whishaw': 80,
#  'typifies': 83,
#  'protestations': 12282,
#  'optimistically': 61827,
#  'errand': 85,
#  'pigalle': 87,
#  'brulier': 88,
#  'gauteng': 90,
#  'conclusiondirector': 91,
#  'govinda': 92,
#  'putdowns': 24645,
#  'seize': 93,
#  'rents': 94,
#  'imperialism': 95,
#  'bugsy': 97,
#  'graber': 101,
#  'carney': 99,
#  'insignificant': 19,
#  'looser': 71238,
#  'geisha': 103,
#  'monogram': 105,
#  'chamionship': 73924,
#  'grieve': 37865,
#  'whoops': 106,
#  'chompers': 109,
#  'reminder': 65832,
#  'bekker': 37074,
#  'pterodactyl': 110,
#  'grainy': 39838,
#  'neuroses': 111,
#  'narcoleptic': 114,
#  'daneldoradoyahoo': 115,
#  'dramatical': 116,
#  'faxes': 118,
#  'democrat': 49536,
#  'gandhian': 120,
#  'escort': 22,
#  'sulley': 46708,
#  'mutates': 122,
#  'dining': 123,
#  'worrying': 124,
#  'plana': 127,
#  'rightful': 126,
#  'columned': 133,
#  'bravura': 130,
#  'franoise': 131,
#  'dougie': 132,
#  'indianised': 135,
#  'greenlit': 136,
#  'mikhalkov': 137,
#  'thatched': 139,
#  'pumped': 140,
#  'meghan': 141,
#  'rolls': 142,
#  'ized': 143,
#  'headings': 144,
#  'nothwest': 37077,
#  'uncovered': 145,
#  'candle': 146,
#  'cod': 147,
#  'alrite': 29,
#  'obtuseness': 149,
#  'wildside': 150,
#  'intruders': 151,
#  'toga': 30424,
#  'capitalizes': 152,
#  'edwedge': 153,
#  'repossessed': 155,
#  'scandi': 37079,
#  'overemoting': 156,
#  'boopous': 157,
#  'socialism': 158,
#  'christien': 69444,
#  'date': 159,
#  'bohnen': 49544,
#  'torrie': 65009,
#  'maclaglen': 66594,
#  'hortyon': 73627,
#  'jelly': 160,
#  'north': 161,
#  'grusomely': 49543,
#  'pokemon': 163,
#  'guyhis': 31811,
#  'manassas': 165,
#  'grier': 61677,
#  'bedsit': 166,
#  'dreamers': 73035,
#  'unsynchronised': 167,
#  'barnacles': 168,
#  'fllm': 169,
#  'undershorts': 49825,
#  'convolutions': 62688,
#  'phieffer': 34,
#  'millardo': 170,
#  'jesues': 171,
#  'sewage': 172,
#  'julliard': 174,
#  'dalrymple': 175,
#  'demerille': 176,
#  'tratment': 177,
#  'deportation': 178,
#  'formulae': 39682,
#  'normative': 180,
#  'anatomie': 181,
#  'frost': 183,
#  'appearing': 185,
#  'camouflaged': 24660,
#  'lupus': 186,
#  'slowdown': 187,
#  'mccullum': 188,
#  'rutledge': 189,
#  'telfair': 191,
#  'nakadai': 192,
#  'unglued': 194,
#  'voce': 195,
#  'sotd': 196,
#  'engrossed': 197,
#  'temporality': 12301,
#  'horrify': 198,
#  'fluent': 199,
#  'brokers': 200,
#  'chemotherapy': 49550,
#  'pak': 201,
#  'lalouche': 61849,
#  'estella': 49552,
#  'delaying': 202,
#  'wotw': 203,
#  'unshakable': 204,
#  'moonstone': 205,
#  'niall': 206,
#  'copulation': 207,
#  'keels': 208,
#  'hoover': 209,
#  'artistes': 210,
#  'bullsh': 211,
#  'unsuccessful': 212,
#  'baaaaad': 213,
#  'unappreciated': 37091,
#  'blob': 214,
#  'heterogeneity': 24663,
#  'leroux': 216,
#  'strudel': 218,
#  'winslet': 219,
#  'gras': 220,
#  'intertwain': 221,
#  'avenues': 222,
#  'untraditional': 223,
#  'legality': 224,
#  'marley': 37094,
#  'fretted': 46792,
#  'summarising': 231,
#  'granddad': 235,
#  'criminality': 229,
#  'chester': 230,
#  'animalplanet': 232,
#  'nadia': 233,
#  'christophe': 236,
#  'inside': 24666,
#  'trema': 237,
#  'brink': 238,
#  'unwholesome': 239,
#  'haarman': 240,
#  'dose': 241,
#  'galaxina': 45,
#  'skoda': 242,
#  'firgens': 247,
#  'froud': 252,
#  'deherrera': 250,
#  'anyhoo': 248,
#  'publicist': 249,
#  'wren': 251,
#  'generalization': 67375,
#  'artefact': 12309,
#  'farina': 253,
#  'endemic': 254,
#  'avantgarde': 12313,
#  'sizzling': 255,
#  'vallejo': 256,
#  'voluntarily': 258,
#  'evocatively': 259,
#  'pelican': 261,
#  'marx': 263,
#  'profligate': 265,
#  'reason': 266,
#  'squirlyem': 68111,
#  'inbound': 268,
#  'afresh': 269,
#  'anais': 270,
#  'corniest': 271,
#  'reuniting': 272,
#  'agitated': 274,
#  'zimmerman': 49,
#  'verdone': 275,
#  'intersection': 277,
#  'panting': 278,
#  'dooooosie': 279,
#  'odor': 280,
#  'bonaerense': 285,
#  'rein': 281,
#  'booooring': 289,
#  'caroll': 284,
#  'unmemorably': 57461,
#  'sanpro': 291,
#  'waite': 287,
#  'mija': 292,
#  'shockwaves': 65897,
#  'nun': 290,
#  'favoritesyou': 293,
#  'guiseppe': 294,
#  'hjelmet': 295,
#  'lucci': 296,
#  'gye': 12321,
#  'humanist': 54780,
#  'gilt': 37102,
#  'sooner': 297,
#  'intergroup': 298,
#  'tenderness': 299,
#  'fbl': 300,
#  'basks': 301,
#  'angle': 302,
#  'guignol': 303,
#  'definitley': 304,
#  'urdu': 305,
#  'irate': 306,
#  'entirelly': 307,
#  'melfi': 49564,
#  'apperance': 310,
#  'imprimatur': 311,
#  'reconstituirea': 312,
#  'funfair': 313,
#  'berkhoff': 37104,
#  'scotch': 314,
#  'bugged': 318,
#  'faux': 316,
#  'andre': 317,
#  'emasculated': 319,
#  'telletubbes': 65540,
#  'burnout': 321,
#  'gunsmoke': 322,
#  'catfights': 324,
#  'sunscreen': 325,
#  'novelized': 57,
#  'tangentially': 326,
#  'melo': 330,
#  'loggia': 329,
#  'dishing': 332,
#  'candyman': 333,
#  'colonialism': 334,
#  'ondrej': 337,
#  'butterick': 338,
#  'mer': 37110,
#  'sixgun': 339,
#  'demoralised': 342,
#  'brand': 60,
#  'leeves': 55466,
#  'jacks': 344,
#  'redoing': 73916,
#  'romford': 345,
#  'farnsworth': 346,
#  'challnges': 347,
#  'tweeners': 49568,
#  'around': 349,
#  'buckaroo': 350,
#  'disinterested': 351,
#  'trashiest': 353,
#  'aghast': 37952,
#  'annex': 354,
#  'artwork': 355,
#  'tact': 357,
#  'hersholt': 363,
#  'fruits': 359,
#  'overshadowing': 361,
#  'squished': 364,
#  'heathcliffe': 365,
#  'letourneau': 366,
#  'szabo': 367,
#  'cheech': 368,
#  'squeals': 369,
#  'fabricated': 61865,
#  'destabilize': 372,
#  'diaboliques': 374,
#  'kennicut': 378,
#  'supertexts': 375,
#  'hokiest': 376,
#  'saratoga': 377,
#  'solvency': 380,
#  'uld': 381,
#  'sinuous': 382,
#  'cardinal': 383,
#  'screwup': 384,
#  'schedulers': 385,
#  'giorgos': 51500,
#  'kyrptonite': 386,
#  'tushies': 387,
#  'baulk': 388,
#  'pics': 389,
#  'schorr': 69315,
#  'enchantment': 391,
#  'eraticate': 392,
#  'idi': 393,
#  'pessimistic': 394,
#  'layton': 395,
#  'sourced': 6059,
#  'undulating': 58812,
#  'mithun': 396,
#  'hobgobblins': 397,
#  'powering': 399,
#  'caravan': 400,
#  'hitchhikers': 401,
#  'undesirables': 404,
#  'oberoi': 403,
#  'lyricists': 37115,
#  'eikenberry': 60858,
#  'totall': 405,
#  'ummmm': 70,
#  'bild': 406,
#  'coyote': 407,
#  'kindled': 408,
#  'doping': 411,
#  'activism': 410,
#  'loafer': 53143,
#  'stapp': 412,
#  'delpy': 413,
#  'jerzee': 423,
#  'bogroll': 417,
#  'sanitizing': 419,
#  'malplaced': 422,
#  'familiarized': 421,
#  'corenblith': 420,
#  'coos': 424,
#  'sugerman': 44942,
#  'cover': 425,
#  'lockley': 49577,
#  'mulgrew': 429,
#  'raking': 428,
#  'bobby': 430,
#  'pirouette': 433,
#  'shiniest': 434,
#  'carlitos': 12342,
#  'slvia': 435,
#  'blooey': 436,
#  'anee': 439,
#  'award': 49580,
#  'russianness': 440,
#  'perrine': 18402,
#  'topped': 441,
#  'leporid': 442,
#  'barcode': 445,
#  'closups': 455,
#  'informed': 448,
#  'stoic': 449,
#  'kidnap': 451,
#  'lashelle': 453,
#  'footages': 23512,
#  'expletive': 454,
#  'cerebrally': 458,
#  'knowledge': 457,
#  'junk': 459,
#  'electricity': 12344,
#  'blinders': 463,
#  'ibanez': 462,
#  'lowrie': 24691,
#  'liquid': 464,
#  'counts': 465,
#  'msf': 466,
#  'core': 467,
#  'preconditions': 468,
#  'exceeded': 469,
#  'grubbing': 470,
#  'sculpts': 61887,
#  'polarizes': 471,
#  'messianistic': 57117,
#  'snort': 72094,
#  'pestilence': 472,
#  'gentleness': 57644,
#  'generification': 473,
#  'ziv': 474,
#  'otherworldly': 475,
#  'cafeteria': 476,
#  'genealogy': 478,
#  'beggins': 479,
#  'schade': 480,
#  'gerhard': 82,
#  'funding': 481,
#  'hitlerthe': 482,
#  'crosscoe': 483,
#  'kerri': 484,
#  'zzzzzzzz': 486,
#  'floradora': 492,
#  'bowen': 487,
#  'commence': 489,
#  'dungeon': 490,
#  'babyhood': 491,
#  'confiscation': 18539,
#  'dreamstate': 12354,
#  'mortar': 493,
#  'scrolls': 24698,
#  'inbreed': 494,
#  'auld': 495,
#  'harping': 496,
#  'mortality': 497,
#  'stymie': 498,
#  'disguise': 499,
#  'bromwell': 500,
#  'fuhrer': 501,
#  'huzzah': 502,
#  'storytellers': 503,
#  'looking': 504,
#  'baxter': 84,
#  'humanimal': 24701,
#  'unfairly': 508,
#  'pup': 510,
#  'plagiarize': 511,
#  'overwhlelming': 517,
#  'egoist': 514,
#  'inventor': 513,
#  'naughtier': 516,
#  'dammes': 515,
#  'leukemia': 24612,
#  'wigged': 86,
#  'dusan': 518,
#  'grispin': 520,
#  'virgine': 525,
#  'confidante': 522,
#  'baldwins': 37128,
#  'teahouse': 524,
#  'inverted': 61897,
#  'uncinematic': 526,
#  'laid': 527,
#  'ladysmith': 45016,
#  'psychosomatic': 528,
#  'infusion': 529,
#  'downgrades': 61899,
#  'distractive': 73807,
#  'ides': 89,
#  'looming': 530,
#  'loulou': 531,
#  'blister': 532,
#  'conspicuous': 533,
#  'fat': 534,
#  'eradicate': 61900,
#  'seafront': 536,
#  'girth': 69537,
#  'hamburgers': 540,
#  'lorica': 538,
#  'ti': 541,
#  'ministry': 542,
#  'undescribably': 64250,
#  'synthesizes': 545,
#  'benet': 548,
#  'interleave': 547,
#  'impartially': 550,
#  'stimulations': 549,
#  'lycanthropy': 551,
#  'blowhards': 552,
#  'mufasa': 553,
#  'kaddiddlehopper': 556,
#  'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz': 557,
#  'calumniated': 47022,
#  'nerdish': 558,
#  'foppish': 559,
#  'guffawed': 560,
#  'cule': 561,
#  'roughie': 562,
#  'tractored': 563,
#  'trattoria': 564,
#  'bmx': 565,
#  'junkies': 566,
#  'klause': 569,
#  'recognizing': 98,
#  'revisiting': 570,
#  'emminently': 49595,
#  'mohicans': 571,
#  'cinematicism': 572,
#  'bredon': 574,
#  'crewed': 576,
#  'bittinger': 577,
#  'irina': 5176,
#  'ravaging': 578,
#  'westbridge': 579,
#  'socioty': 580,
#  'predilections': 102,
#  'speedy': 582,
#  'expanse': 583,
#  'yeop': 584,
#  'suderland': 12371,
#  'natella': 585,
#  'elly': 586,
#  'achilles': 587,
#  'differentiating': 12369,
#  'shotguns': 52114,
#  'assessments': 589,
#  'mounds': 590,
#  'elton': 591,
#  'worry': 104,
#  'adachi': 593,
#  'purport': 594,
#  'ate': 595,
#  'tipp': 597,
#  'mcdoakes': 598,
#  'sand': 599,
#  'demonstration': 61912,
#  'militarily': 600,
#  'fascistoid': 49601,
#  'urucows': 37140,
#  'injuries': 601,
#  'fairer': 58011,
#  'gianni': 602,
#  'insinuates': 603,
#  'teeeell': 604,
#  'wust': 605,
#  'sogo': 606,
#  'gallows': 607,
#  'tomie': 608,
#  'stakes': 49603,
#  'blockhead': 611,
#  'nativity': 610,
#  'steamers': 612,
#  'alte': 613,
#  'mosaic': 616,
#  'belongings': 615,
#  'slapsticks': 45615,
#  'ursla': 618,
#  'naboombu': 620,
#  'outclasses': 69730,
#  'overtaking': 4784,
#  'kickboxer': 621,
#  'differential': 622,
#  'unzip': 623,
#  'manat': 627,
#  'pastor': 625,
#  'promoting': 628,
#  'katch': 629,
#  'call': 631,
#  'bellyaching': 14152,
#  'conservation': 632,
#  'rodeos': 37150,
#  'khialdi': 633,
#  'uninformative': 634,
#  'quicksilver': 638,
#  'kyonki': 637,
#  'precedence': 24718,
#  'analysts': 639,
#  'pecks': 49611,
#  'wagner': 640,
#  'bejarano': 119,
#  'acing': 641,
#  'chancers': 24721,
#  'roommates': 642,
#  'femi': 644,
#  'vegetarians': 37152,
#  'pearly': 645,
#  'contracter': 113,
#  'plummeting': 646,
#  'af': 652,
#  'wahhhhh': 648,
#  've': 649,
#  'straddling': 650,
#  'nation': 651,
#  'schmoozed': 653,
#  'banjos': 654,
#  'hears': 26684,
#  'angles': 61918,
#  'succinctly': 655,
#  'absentee': 656,
#  'fogged': 62615,
#  'shahrukhed': 39692,
#  'australian': 658,
#  'tohs': 659,
#  'germaphobe': 660,
#  'imprisoning': 661,
#  'truism': 662,
#  'disase': 663,
#  'butt': 664,
#  'stanojlo': 668,
#  'penitently': 667,
#  'probate': 669,
#  'farming': 670,
#  'preempt': 61920,
#  'nastiness': 671,
#  'imaginable': 672,
#  'tolkein': 673,
#  'formulatic': 674,
#  'loek': 675,
#  'sharpens': 676,
#  'devolved': 677,
#  'swooned': 679,
#  'opus': 681,
#  'wealthiest': 682,
#  'glommed': 683,
#  'equivalence': 72279,
#  'insinuations': 684,
#  'objectification': 685,
#  'kant': 121,
#  'scoundrel': 687,
#  'cena': 688,
#  'fingertips': 689,
#  'immorality': 49617,
#  'shabnam': 690,
#  'birdie': 691,
#  'weel': 693,
#  'align': 694,
#  'sharps': 695,
#  'usaf': 696,
#  'krell': 698,
#  'immense': 699,
#  'forestry': 61927,
#  'chetas': 700,
#  'farligt': 69706,
#  'corto': 701,
#  'targetting': 702,
#  'schappert': 703,
#  'workers': 705,
#  'occultism': 711,
#  'queen': 707,
#  'soulful': 708,
#  'helmuth': 710,
#  'launchpad': 37168,
#  'stros': 712,
#  'booker': 713,
#  'spitted': 714,
#  'neurotics': 715,
#  'tuberculosis': 716,
#  'strikebreakers': 125,
#  'impressionism': 727,
#  'apocryphal': 722,
#  'rape': 720,
#  'symbolizations': 724,
#  'benevolent': 723,
#  'beringer': 725,
#  'bingen': 728,
#  'gethsemane': 729,
#  'placidly': 730,
#  'hesitancy': 732,
#  'ingredients': 734,
#  'manhandles': 735,
#  'easily': 736,
#  'koenigsegg': 61934,
#  'dull': 738,
#  'rugby': 739,
#  'drivvle': 37170,
#  'minty': 741,
#  'unforgiving': 742,
#  'schizoid': 12392,
#  'shank': 744,
#  'effervescent': 128,
#  'imprison': 746,
#  'transatlantic': 747,
#  'tendo': 748,
#  'legal': 129,
#  'alladin': 12397,
#  'averagousity': 749,
#  'harried': 750,
#  'fitted': 751,
#  'wanderers': 753,
#  'ludivine': 761,
#  'muro': 755,
#  'waxworks': 756,
#  'emma': 757,
#  'clichs': 758,
#  'fragmentaric': 760,
#  'borkowski': 37175,
#  'ritterkreuz': 762,
#  'implanted': 763,
#  'conjoined': 764,
#  'potenta': 765,
#  'poly': 45485,
#  'salum': 134,
#  'chocking': 767,
#  'phelps': 768,
#  'tilton': 769,
#  'lilith': 5167,
#  'scrapbook': 770,
#  'farreley': 771,
#  'perabo': 772,
#  'tarrinno': 773,
#  'ib': 68777,
#  'sobbingly': 774,
#  'amat': 775,
#  'illuminator': 776,
#  'oral': 777,
#  'arsehole': 779,
#  'disappointment': 781,
#  'launch': 782,
#  'regarding': 65944,
#  'prohibitions': 784,
#  'seasickness': 785,
#  'hopkirk': 786,
#  'elucubrate': 787,
#  'keanu': 788,
#  'darstardy': 789,
#  'forrest': 790,
#  'photos': 791,
#  'hotheads': 792,
#  'nickelodean': 793,
#  'cresus': 794,
#  'oirish': 24743,
#  'somberness': 795,
#  'americanizing': 70211,
#  'defenseless': 796,
#  'dalle': 797,
#  'horrifically': 798,
#  'trifling': 800,
#  'intersperse': 804,
#  'kimosabe': 49636,
#  'synopsize': 803,
#  'bobbies': 70503,
#  'piecing': 805,
#  'woodchipper': 806,
#  'decieve': 807,
#  'emmanuelle': 808,
#  'sandlers': 809,
#  'horrorfilm': 810,
#  'jeeves': 811,
#  'mockmuntaries': 816,
#  'ieeee': 815,
#  'heather': 814,
#  'classicists': 822,
#  'ridley': 818,
#  'guility': 819,
#  'haiduck': 823,
#  'deployments': 37197,
#  'inacessible': 46815,
#  'petey': 825,
#  'eastwoods': 826,
#  'sinbad': 828,
#  'lashley': 829,
#  'mandibles': 831,
#  'simulated': 830,
#  'shard': 832,
#  'disengorges': 833,
#  'recants': 71412,
#  'unalike': 65136,
#  'misguide': 31752,
#  'prat': 835,
#  'panettiere': 836,
#  'kenovic': 838,
#  'admitt': 839,
#  'newcastle': 840,
#  'slayn': 841,
#  'cappomaggi': 842,
#  'yauman': 843,
#  'obligations': 48159,
#  'wu': 844,
#  'dispassionate': 846,
#  'giurgiu': 847,
#  'comparative': 67193,
#  'scaramouche': 849,
#  'bruckheimer': 850,
#  'engraved': 851,
#  'unearp': 852,
#  'misperceived': 853,
#  'ipcress': 854,
#  'coda': 36903,
#  'stella': 856,
#  'hotdog': 857,
#  'intending': 61951,
#  'lerner': 859,
#  'albizu': 65059,
#  'grimstead': 861,
#  'notit': 61953,
#  'justifies': 862,
#  'plastrons': 866,
#  'motherly': 864,
#  'dantesque': 865,
#  'paheli': 55792,
#  'seppuku': 12409,
#  'effacing': 18142,
#  'trample': 867,
#  'coolish': 869,
#  'explainable': 53053,
#  'telekinesis': 44560,
#  'aip': 872,
#  'shakiness': 873,
#  'weinzweig': 61955,
#  'estimate': 874,
#  'lash': 875,
#  'discontents': 877,
#  'brickman': 878,
#  'fails': 879,
#  'yorga': 880,
#  'pocket': 881,
#  'indolently': 882,
#  'characterisation': 883,
#  'halop': 884,
#  'mger': 885,
#  'poachers': 49649,
#  'murphy': 887,
#  'elven': 61959,
#  'adolescent': 888,
#  'normals': 12414,
#  'iliad': 889,
#  'telephones': 69631,
#  'wantabedde': 12419,
#  'dodged': 890,
#  'utilises': 12412,
#  'scarry': 72020,
#  'rippings': 154,
#  'gunslinging': 37209,
#  'lena': 61965,
#  'masochism': 891,
#  'amusements': 892,
#  'imagesi': 893,
#  'unshowy': 894,
#  'indecision': 898,
#  'ventured': 899,
#  'unflattering': 57367,
#  'proclaimed': 900,
#  'wardrobes': 901,
#  'wrangler': 61966,
#  'snider': 905,
#  'banned': 903,
#  'sexiest': 904,
#  'magna': 906,
#  'muddies': 907,
#  'humongous': 908,
#  'disillusioning': 910,
#  'beuneau': 24765,
#  'choreographer': 67934,
#  'taught': 911,
#  'longed': 912,
#  'caleb': 913,
#  'maul': 49653,
#  'hucksters': 914,
#  'eeeeh': 915,
#  'heyward': 916,
#  'untypically': 919,
#  'pols': 921,
#  'inwardly': 922,
#  'percepts': 925,
#  'rotj': 926,
#  'ducky': 927,
#  'aby': 929,
#  'shagayu': 930,
#  'heathers': 66965,
#  'scareless': 61472,
#  'mirrors': 932,
#  'stunning': 933,
#  'doses': 934,
#  'given': 935,
#  'androgynous': 936,
#  'faustino': 937,
#  'embraces': 939,
#  'electric': 940,
#  'starchy': 941,
#  'yugoslavian': 162,
#  'lafanu': 942,
#  'fincher': 943,
#  'panties': 944,
#  'tin': 37216,
#  'heyerdahl': 945,
#  'snuff': 67516,
#  'ntuba': 946,
#  'merit': 947,
#  'divulged': 948,
#  'potboiler': 949,
#  'suddenness': 951,
#  'puertorican': 61978,
#  'imparts': 953,
#  'wnk': 954,
#  'bulworth': 955,
#  'calvary': 956,
#  'phoned': 957,
#  'meaneys': 958,
#  'troops': 959,
#  'weirdos': 962,
#  'pulitzer': 961,
#  'goldstien': 24777,
#  'pequod': 964,
#  'lizabeth': 965,
#  'leeched': 966,
#  'jealousy': 967,
#  'twistings': 969,
#  'alchemical': 12431,
#  'decadent': 970,
#  'hold': 972,
#  'danniele': 973,
#  'regeneration': 974,
#  'zaz': 977,
#  'latching': 976,
#  'smita': 70217,
#  'compiler': 980,
#  'soto': 979,
#  'muggy': 57998,
#  'sacrificies': 66268,
#  'midge': 12434,
#  'cosimo': 981,
#  'wil': 982,
#  'hardest': 983,
#  'yardley': 37230,
#  'godzillasaurus': 24780,
#  'sheffer': 73563,
#  'chin': 984,
#  'eeeee': 24782,
#  'allende': 985,
#  'gorehounds': 986,
#  'ouroboros': 988,
#  'zig': 989,
#  'labs': 990,
#  'bick': 59540,
#  'dalliance': 991,
#  'prc': 992,
#  'rhetorical': 62460,
#  'commendation': 993,
#  'teenth': 72025,
#  'manchu': 37233,
#  'ana': 994,
#  'uninterrupted': 65213,
#  'rinse': 12440,
#  'empathetic': 37234,
#  'euthanasia': 25414,
#  'brutally': 12439,
#  'melding': 995,
#  'raily': 998,
#  'studies': 999,
#  'dugdale': 1000,
#  'harass': 1001,
#  'starringsean': 1002,
#  'cher': 1003,
#  'kinds': 1005,
#  'luigi': 1006,
#  'recruitment': 26848,
#  'plato': 1007,
#  ...}

# %%
label2index
# Out:
# {'NEGATIVE': 1, 'POSITIVE': 0}

# %%
learning_rate = 0.1
epochs = 20
batch_size = 120
display_step = 1

n_input = review_vocab_size
n_classes = label_vocab_size
hidden_layer = 10

# %%
weights = {
    'hidden_layer': tf.Variable(tf.random_normal([n_input, hidden_layer])),
    'out': tf.Variable(tf.random_normal([hidden_layer, n_classes]))
}

biases = {
    'hidden_layer': tf.Variable(tf.random_normal([hidden_layer])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
x = tf.placeholder("float32", [None, n_input])
y = tf.placeholder("float32", [None, n_classes])

# %%
layer = tf.add(tf.matmul(x, weights['hidden_layer']), biases['hidden_layer'])
layer = tf.nn.relu(layer)

logits = tf.add(tf.matmul(layer, weights['out']), biases['out'])

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
def get_x(x):
    batch_x = np.zeros((1, review_vocab_size))
    
    for word in x.split(' '):
        if (word in word2index.keys()):
            batch_x[0][word2index[word]] = 1
    
    return batch_x

def get_y(y):
    batch_y = np.zeros((1, label_vocab_size))
    if train_y[i] == 'POSITIVE':
        batch_y[0][1] = 1
    else:
        batch_y[0][0] = 1
        
    return batch_y
            
            
init = tf.global_variables_initializer()
# saver = tf.train.Saver()

train_x = reviews[:-10]
train_y = labels[:-10]

test_x = [get_x(reviews[24999 - i]) for i in range(len(reviews[-1000:]))]
test_y = [get_y(labels[24999 - i]) for i in range(len(labels[-1000:]))]

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    # Training cycle
    for epoch in range(1):
#         total_batch = int(len(train_x) / batch_size)
        # Loop over all batches
        for i in range(len(train_x)):
#             batch_x = train_x[i * batch_size:(i + 1) * batch_size]
#             batch_y = train_y[i * batch_size:(i + 1) * batch_size]
            batch_x = get_x(train_x[i])
            batch_y = get_y(train_y[i])
            
            # Run optimization op (backprop) and cost op (to get loss value)
            sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        # Display logs per epoch step
#         if epoch % 0 == 0:
        c = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
        print("Epoch:", '%04d' % (epoch+1), "cost=", \
            "{:.9f}".format(c))
#     saver.save(sess, save_file)
    print("Optimization Finished!")

#     # Test model
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
#     # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
#     # Decrease test_size if you don't have enough memory
#     test_size = 256
    print("Accuracy:", accuracy.eval({x: test_x, y: test_y}))
# Out:
# Epoch: 0001 cost= 0.667817056
# Optimization Finished!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-4ea94b206ce1> in <module>()
#      55 #     # Decrease test_size if you don't have enough memory
#      56 #     test_size = 256
# ---> 57     print("Accuracy:", accuracy.eval({x: test_x, y: test_y}))
#
# /Users/max/anaconda/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     579
#     580     """
# --> 581     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     582
#     583
#
# /Users/max/anaconda/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3795                        "the tensor's graph is different from the session's "
#    3796                        "graph.")
# -> 3797   return session.run(tensors, feed_dict)
#    3798
#    3799
#
# /Users/max/anaconda/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/max/anaconda/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     942                 'Cannot feed value of shape %r for Tensor %r, '
#     943                 'which has shape %r'
# --> 944                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     945           if not self.graph.is_feedable(subfeed_t):
#     946             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (1000, 1, 74074) for Tensor 'Placeholder:0', which has shape '(?, 74074)'
